# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0c7b6a61-cc1e-49bd-bfab-6278d6ddec67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c7b6a61-cc1e-49bd-bfab-6278d6ddec67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kc_house_data.csv to kc_house_data.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['kc_house_data.csv']))

# %%
df.head()
# Out:
#            id        date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1  6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2  5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3  2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4  1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.describe().transpose()
# Out:
#                  count          mean  ...           75%           max
# id             21597.0  4.580474e+09  ...  7.308900e+09  9.900000e+09
# price          21597.0  5.402966e+05  ...  6.450000e+05  7.700000e+06
# bedrooms       21597.0  3.373200e+00  ...  4.000000e+00  3.300000e+01
# bathrooms      21597.0  2.115826e+00  ...  2.500000e+00  8.000000e+00
# sqft_living    21597.0  2.080322e+03  ...  2.550000e+03  1.354000e+04
# sqft_lot       21597.0  1.509941e+04  ...  1.068500e+04  1.651359e+06
# floors         21597.0  1.494096e+00  ...  2.000000e+00  3.500000e+00
# waterfront     21597.0  7.547345e-03  ...  0.000000e+00  1.000000e+00
# view           21597.0  2.342918e-01  ...  0.000000e+00  4.000000e+00
# condition      21597.0  3.409825e+00  ...  4.000000e+00  5.000000e+00
# grade          21597.0  7.657915e+00  ...  8.000000e+00  1.300000e+01
# sqft_above     21597.0  1.788597e+03  ...  2.210000e+03  9.410000e+03
# ...

# %%
plt.figure(figsize=(10,7))
sns.distplot(df['price'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(df['bedrooms'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(10, 7))
sns.boxplot(x='grade', y='sqft_above', data=df)

# %%
correlations = df.corr()

f, ax = plt.subplots(figsize = (15,15))
sns.heatmap(correlations, annot = True)

# %%
# Grade, sqft living, and sqft above all have strong correlations with price
# Grade is strongly correlated with price, number of bathrooms, sqft living., sqft above, and sqft lot15
# I personally thought # of bedrooms and floors would have a higher correlation with price

# %%
sns.boxplot(x='bedrooms',y='price',data=df)

# %%
sns.boxplot(x='floors',y='price',data=df)
# 2.5 floors were amongst the highest valued homes

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='price',y='sqft_living',data=df)

# %%
sns.boxplot(x='waterfront',y='price',data=df)

# %%
# It seems that waterfront homes have a higher value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.drop('id', axis=1, inplace=True)

# %%
df.head()
# Out:
#          date     price  bedrooms  ...     long  sqft_living15  sqft_lot15
# 0  10/13/2014  221900.0         3  ... -122.257           1340        5650
# 1   12/9/2014  538000.0         3  ... -122.319           1690        7639
# 2   2/25/2015  180000.0         2  ... -122.233           2720        8062
# 3   12/9/2014  604000.0         4  ... -122.393           1360        5000
# 4   2/18/2015  510000.0         3  ... -122.045           1800        7503
#
# [5 rows x 20 columns]

# %%
# Convert strings to datetime objects
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].apply(lambda date:date.year)

# %%
sns.boxplot(x='year',y='price',data=df)

# %%
# Seems that year purchased doesn't have much effect
# Going to remove date

# %%
# df['zipcode'].value_counts()
# cannot locate zipcode column

# %%
df.drop(columns = ['date', 'year'], inplace = True)

# %%
# Going to map latitude and longitude

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='price',y='long',data=df)

# There are higher valued homes near 122.2 longitude

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='price',y='lat',data=df)

# There are higher valued homes between 47.6 - 47.7 latitudes

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x='long',y='lat',data=df,hue='price')

# %%
# Looks like the lat/long pointed out do match up
# Also looks like waterfront properties can have higher values, as observed earlier
# I was hoping for more color gradiation, so going to filter out outliers

# %%
df.sort_values('price',ascending=False).head(15)
# Out:
#            price  bedrooms  bathrooms  ...     long  sqft_living15  sqft_lot15
# 7245   7700000.0         6       8.00  ... -122.323           3940        8800
# 3910   7060000.0         5       4.50  ... -122.214           3930       25449
# 9245   6890000.0         6       7.75  ... -122.240           4540       42730
# 4407   5570000.0         5       5.75  ... -122.233           3560       24345
# 1446   5350000.0         5       5.00  ... -122.220           4600       21750
# 1313   5300000.0         6       6.00  ... -122.210           4320       24619
# 1162   5110000.0         5       5.25  ... -122.211           3430       26788
# 8085   4670000.0         5       6.75  ... -122.210           3270       10454
# 2624   4500000.0         5       5.50  ... -122.280           3030       23408
# 8629   4490000.0         4       3.00  ... -122.219           3720       14592
# 12358  4210000.0         5       6.00  ... -122.189           4740       19329
# ...

# %%
len(df)
# Out:
# 21597

# %%
# Take out the top 1%
len(df) * (0.01)
# Out:
# 215.97

# %%
bottom_99_percent = df.sort_values('price',ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='long', y='lat', data=bottom_99_percent, hue='price', edgecolor = None, alpha = 0.2)

# %%
# Train Test Split
# Drop target variable

X = df.drop('price',axis=1)
y = df['price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (15117, 17)

# %%
X_test.shape
# Out:
# (6480, 17)

# %%
# Build Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam

# %%
model = Sequential()

model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(19,activation='relu'))
model.add(Dense(1))

model.compile(optimizer='adam',loss='mse')

# %%
model.fit(x=X_train,y=y_train.values,
          validation_data=(X_test,y_test.values),
          batch_size=128,epochs=400)

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score

# %%
X_test
# Out:
# array([[0.1       , 0.08      , 0.04239917, ..., 0.18189369, 0.31337119,
#         0.00887725],
#        [0.3       , 0.36      , 0.17269907, ..., 0.27740864, 0.35639305,
#         0.00993734],
#        [0.2       , 0.24      , 0.12512927, ..., 0.12292359, 0.16365514,
#         0.00547073],
#        ...,
#        [0.1       , 0.08      , 0.05584281, ..., 0.1179402 , 0.18086388,
#         0.00506255],
#        [0.3       , 0.2       , 0.22233713, ..., 0.27159468, 0.33746343,
#         0.00774485],
#        [0.3       , 0.32      , 0.27611169, ..., 0.22840532, 0.33057993,
#         0.0196531 ]])

# %%
predictions = model.predict(X_test)

# %%
mean_absolute_error(y_test,predictions)
# Out:
# 103363.64053096065

# %%
# not that great

# %%
np.sqrt(mean_squared_error(y_test,predictions))
# Out:
# 166023.7793169775

# %%
explained_variance_score(y_test,predictions)
# just okay
# Out:
# 0.792360414661799

# %%
df['price'].mean()
# Out:
# 540296.5735055795

# %%
df['price'].median()
# Out:
# 450000.0

# %%
# compare predictions against a perfect fit

plt.scatter(y_test,predictions)

plt.plot(y_test,y_test,'r')

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...     long  sqft_living15  sqft_lot15
# 0      221900.0         3       1.00  ... -122.257           1340        5650
# 1      538000.0         3       2.25  ... -122.319           1690        7639
# 2      180000.0         2       1.00  ... -122.233           2720        8062
# 3      604000.0         4       3.00  ... -122.393           1360        5000
# 4      510000.0         3       2.00  ... -122.045           1800        7503
# ...         ...       ...        ...  ...      ...            ...         ...
# 21592  360000.0         3       2.50  ... -122.346           1530        1509
# 21593  400000.0         4       2.50  ... -122.362           1830        7200
# 21594  402101.0         2       0.75  ... -122.299           1020        2007
# 21595  400000.0         3       2.50  ... -122.069           1410        1287
# 21596  325000.0         2       0.75  ... -122.299           1020        1357
#
# [21597 rows x 18 columns]

# %%
# Predict for one house
df.drop('price', axis = 1).iloc[0]
# Out:
# bedrooms            3.0000
# bathrooms           1.0000
# sqft_living      1180.0000
# sqft_lot         5650.0000
# floors              1.0000
# waterfront          0.0000
# view                0.0000
# condition           3.0000
# grade               7.0000
# sqft_above       1180.0000
# sqft_basement       0.0000
# yr_built         1955.0000
# yr_renovated        0.0000
# lat                47.5112
# long             -122.2570
# sqft_living15    1340.0000
# sqft_lot15       5650.0000
# Name: 0, dtype: float64

# %%
single_house = df.drop('price', axis = 1).iloc[0]

# %%
single_house.values
# Out:
# array([ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#         1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#         7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#         0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#         5.65000e+03])

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 17))

# %%
single_house
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059]])

# %%
model.predict(single_house)
# Out:
# array([[288507.06]], dtype=float32)

# %%
df.iloc[0]
# Out:
# price            221900.0000
# bedrooms              3.0000
# bathrooms             1.0000
# sqft_living        1180.0000
# sqft_lot           5650.0000
# floors                1.0000
# waterfront            0.0000
# view                  0.0000
# condition             3.0000
# grade                 7.0000
# sqft_above         1180.0000
# sqft_basement         0.0000
# yr_built           1955.0000
# yr_renovated          0.0000
# lat                  47.5112
# long               -122.2570
# sqft_living15      1340.0000
# sqft_lot15         5650.0000
# Name: 0, dtype: float64
